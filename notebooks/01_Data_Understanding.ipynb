# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../northbeam_accounts.csv")

# %%
df.head()
# Out:
#   account_id        account_name     segment     industry         region  \
# 0   ACC-1132     Solace Holdings  Mid-Market    Logistics  North America
# 1   ACC-1341      Cedar Partners  Mid-Market  Hospitality           EMEA
# 2   ACC-1118   Nimbus Industries         SMB    Logistics  North America
# 3   ACC-1212          Helix Labs  Mid-Market       Retail  North America
# 4   ACC-1096  Quill Technologies         SMB         SaaS  North America
#
#   signup_date contract_start_date contract_end_date billing_term  \
# 0  25/12/2024          25/12/2024        25/12/2026      monthly
# 1  28/01/2025          28/01/2025        04/12/2026       annual
# 2  29/01/2024          29/01/2024        28/12/2026       annual
# 3  13/04/2023          13/04/2023        23/06/2027       annual
# 4  05/06/2024          05/06/2024        19/06/2026       annual
#
#    contract_value  ...  mau_m5  mau_m4  mau_m3  mau_m2  mau_m1  mau_m0  \
# 0         1660.09  ...       0       1       1       1       1       1
# 1        67135.04  ...       0       0       9       5      11       2
# 2         5723.84  ...      10      10      11      11      11      10
# 3        61588.39  ...      62      53      40      33      25      14
# 4         2765.58  ...       9       7       6       4       3       2
#
#    support_tickets_90d  escalations_90d  last_login_date  csat
# 0                    6                0       22/05/2026   NaN
# 1                    0                0       20/05/2026   4.3
# 2                    6                1       23/05/2026   NaN
# 3                    7                0       14/05/2026   3.1
# 4                    1                0       29/05/2026   NaN
#
# [5 rows x 22 columns]

# %%
print("Rows :", df.shape[0])
print("Columns :", df.shape[1])
# Out:
# Rows : 424
# Columns : 22

# %%
df.columns
# Out:
# Index(['account_id', 'account_name', 'segment', 'industry', 'region',
#        'signup_date', 'contract_start_date', 'contract_end_date',
#        'billing_term', 'contract_value', 'seats_licensed', 'seats_active',
#        'mau_m5', 'mau_m4', 'mau_m3', 'mau_m2', 'mau_m1', 'mau_m0',
#        'support_tickets_90d', 'escalations_90d', 'last_login_date', 'csat'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 424 entries, 0 to 423
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   account_id           424 non-null    str
#  1   account_name         424 non-null    str
#  2   segment              410 non-null    str
#  3   industry             424 non-null    str
#  4   region               424 non-null    str
#  5   signup_date          424 non-null    str
#  6   contract_start_date  424 non-null    str
#  7   contract_end_date    421 non-null    str
#  8   billing_term         424 non-null    str
#  9   contract_value       424 non-null    float64
#  10  seats_licensed       424 non-null    int64
#  11  seats_active         424 non-null    int64
#  12  mau_m5               424 non-null    int64
#  13  mau_m4               424 non-null    int64
#  14  mau_m3               424 non-null    int64
#  15  mau_m2               424 non-null    int64
#  16  mau_m1               424 non-null    int64
#  17  mau_m0               424 non-null    int64
#  18  support_tickets_90d  424 non-null    int64
#  19  escalations_90d      424 non-null    int64
#  20  last_login_date      424 non-null    str
#  21  csat                 194 non-null    float64
# dtypes: float64(2), int64(10), str(10)
# memory usage: 73.0 KB

# %%
df.describe()
# Out:
#        contract_value  seats_licensed  seats_active       mau_m5       mau_m4  \
# count    4.240000e+02      424.000000    424.000000   424.000000   424.000000
# mean     9.192647e+04      201.580189    135.537736    82.992925    81.372642
# std      2.158869e+05      327.647670    242.502884   169.800766   164.123873
# min     -4.500000e+03        5.000000      2.000000     0.000000     0.000000
# 25%      3.544005e+03       25.000000     17.000000     5.000000     5.000000
# 50%      9.726250e+03       68.000000     40.000000    18.500000    18.000000
# 75%      7.260744e+04      200.250000    127.000000    74.250000    69.250000
# max      1.322116e+06     1488.000000   1301.000000  1206.000000  1151.000000
#
#             mau_m3       mau_m2       mau_m1       mau_m0  \
# count   424.000000   424.000000   424.000000   424.000000
# mean     77.608491    71.823113    69.214623    65.181604
# std     153.878978   150.319060   148.807915   153.742770
# min       0.000000     0.000000     0.000000     0.000000
# 25%       5.000000     3.000000     3.000000     1.000000
# 50%      19.000000    16.000000    15.500000    13.000000
# 75%      72.000000    68.250000    70.000000    60.250000
# max    1147.000000  1080.000000  1069.000000  1154.000000
#
#        support_tickets_90d  escalations_90d        csat
# count           424.000000       424.000000  194.000000
# mean              4.573113         0.747642    3.708763
# std               2.629948         0.891247    0.674537
# min               0.000000         0.000000    2.500000
# 25%               3.000000         0.000000    3.100000
# 50%               4.000000         1.000000    3.700000
# 75%               6.000000         1.000000    4.200000
# max              13.000000         6.000000    5.000000

# %%
df.describe(include='object')
# Out:
# C:\Users\raj41\AppData\Local\Temp\ipykernel_5192\87514550.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.describe(include='object')
#        account_id     account_name segment industry         region  \
# count         424              424     410      424            424
# unique        424              424       3       10              4
# top      ACC-1132  Solace Holdings     SMB     SaaS  North America
# freq            1                1     181       58            216
#
#        signup_date contract_start_date contract_end_date billing_term  \
# count          424                 424               421          424
# unique         367                 367               300            2
# top     05/06/2024          05/06/2024        28/09/2026       annual
# freq             3                   3                 5          294
#
#        last_login_date
# count              424
# unique              61
# top         30/05/2026
# freq                30

# %%
df.isnull().sum()
# Out:
# account_id               0
# account_name             0
# segment                 14
# industry                 0
# region                   0
# signup_date              0
# contract_start_date      0
# contract_end_date        3
# billing_term             0
# contract_value           0
# seats_licensed           0
# seats_active             0
# mau_m5                   0
# mau_m4                   0
# mau_m3                   0
# mau_m2                   0
# mau_m1                   0
# mau_m0                   0
# support_tickets_90d      0
# escalations_90d          0
# last_login_date          0
# csat                   230
# dtype: int64

# %%
print("Duplicate Rows :", df.duplicated().sum())
# Out:
# Duplicate Rows : 0

# %% [markdown]
# Unique Values in Categorical Columns

# %%
categorical_cols = df.select_dtypes(include='object').columns

for col in categorical_cols:
    print("="*40)
    print(col)
    print(df[col].unique())
    print()
# Out:
# ========================================
# account_id
# <StringArray>
# ['ACC-1132', 'ACC-1341', 'ACC-1118', 'ACC-1212', 'ACC-1096', 'ACC-1052',
#  'ACC-1414', 'ACC-1031', 'ACC-1271', 'ACC-1382',
#  ...
#  'ACC-1398', 'ACC-1185', 'ACC-1348', 'ACC-1103', 'ACC-1407', 'ACC-1211',
#  'ACC-1067', 'ACC-1025', 'ACC-1196', 'ACC-1175']
# Length: 424, dtype: str
#
# ========================================
# account_name
# <StringArray>
# [   'Solace Holdings',     'Cedar Partners',  'Nimbus Industries',
#          'Helix Labs', 'Quill Technologies',     'Redwood Health',
#       'Yarrow Health',    'Crestline Works',       'Yarrow Media',
#       'Quill Trading',
#  ...
#         'Vista Works',       'Xenon Health',       'Juniper Corp',
#         'Harbor Corp', 'Crestline Holdings',         'Atlas Corp',
#         'Zephyr Labs',         'Maple Corp',       'Harbor Media',
#     'Zephyr Dynamics']
# Length: 424, dtype: str
#
# ========================================
# segment
# <StringArray>
# ['Mid-Market', 'SMB', 'Enterprise', nan]
# Length: 4, dtype: str
#
# ========================================
# industry
# <StringArray>
# [    'Logistics',   'Hospitality',        'Retail',          'SaaS',
#          'Media', 'Manufacturing',       'FinServ',    'Healthcare',
#   'Construction',     'Education']
# Length: 10, dtype: str
#
# ========================================
# region
# <StringArray>
# ['North America', 'EMEA', 'APAC', 'LATAM']
# Length: 4, dtype: str
#
# ========================================
# signup_date
# <StringArray>
# ['25/12/2024', '28/01/2025', '29/01/2024', '13/04/2023', '05/06/2024',
#  '05/06/2022', '05/08/2024', '20/03/2025', '25/04/2026', '26/01/2026',
#  ...
#  '12/02/2023', '08/10/2024', '20/05/2025', '15/06/2023', '13/07/2023',
#  '18/04/2026', '23/04/2025', '14/07/2022', '16/09/2023', '01/04/2026']
# Length: 367, dtype: str
#
# ========================================
# contract_start_date
# <StringArray>
# ['25/12/2024', '28/01/2025', '29/01/2024', '13/04/2023', '05/06/2024',
#  '05/06/2022', '05/08/2024', '20/03/2025', '25/04/2026', '26/01/2026',
#  ...
#  '12/02/2023', '08/10/2024', '20/05/2025', '15/06/2023', '13/07/2023',
#  '18/04/2026', '23/04/2025', '14/07/2022', '16/09/2023', '01/04/2026']
# Length: 367, dtype: str
#
# ========================================
# contract_end_date
# <StringArray>
# ['25/12/2026', '04/12/2026', '28/12/2026', '23/06/2027', '19/06/2026',
#  '30/03/2026', '20/06/2027', '06/09/2026', '20/04/2027', '27/04/2027',
#  ...
#  '15/01/2027', '14/03/2026', '20/12/2026', '17/12/2026', '09/12/2026',
#  '20/08/2026', '24/03/2026', '13/04/2027', '31/03/2026', '16/09/2027']
# Length: 301, dtype: str
#
# ========================================
# billing_term
# <StringArray>
# ['monthly', 'annual']
# Length: 2, dtype: str
#
# ========================================
# last_login_date
# <StringArray>
# ['22/05/2026', '20/05/2026', '23/05/2026', '14/05/2026', '29/05/2026',
#  '04/02/2026', '26/02/2026', '25/05/2026', '26/05/2026', '31/05/2026',
#  '03/03/2026', '24/05/2026', '15/05/2026', '26/12/2025', '28/05/2026',
#  '30/05/2026', '18/05/2026', '21/05/2026', '29/03/2026', '01/06/2026',
#  '19/05/2026', '14/12/2025', '27/05/2026', '13/05/2026', '16/05/2026',
#  '17/05/2026', '12/10/2025', '19/11/2025', '13/04/2026', '05/03/2026',
#  '28/03/2026', '11/04/2026', '03/02/2026', '12/02/2026', '16/03/2026',
#  '14/03/2026', '18/04/2026', '30/11/2025', '01/02/2026', '17/02/2026',
#  '19/04/2026', '10/04/2026', '24/03/2026', '31/12/2025', '20/02/2026',
#  '05/10/2025', '03/04/2026', '05/02/2026', '31/10/2025', '05/01/2026',
#  '16/09/2025', '14/11/2025', '04/03/2026', '01/03/2026', '24/04/2026',
#  '24/02/2026', '21/04/2026', '26/09/2025', '08/11/2025', '16/11/2025',
#  '28/02/2026']
# Length: 61, dtype: str
# C:\Users\raj41\AppData\Local\Temp\ipykernel_5192\523817765.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   categorical_cols = df.select_dtypes(include='object').columns

# %%
df.dtypes
# Out:
# account_id                 str
# account_name               str
# segment                    str
# industry                   str
# region                     str
# signup_date                str
# contract_start_date        str
# contract_end_date          str
# billing_term               str
# contract_value         float64
# seats_licensed           int64
# seats_active             int64
# mau_m5                   int64
# mau_m4                   int64
# mau_m3                   int64
# mau_m2                   int64
# mau_m1                   int64
# mau_m0                   int64
# support_tickets_90d      int64
# escalations_90d          int64
# last_login_date            str
# csat                   float64
# dtype: object

# %%
df.hist(figsize=(15,10))
plt.show()
