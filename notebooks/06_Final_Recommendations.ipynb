# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../top_40_priority_customers.csv")

# %%
df.head()
# Out:
#   account_id      account_name     segment       industry         region  \
# 0   ACC-1235   Larkfield Foods  Mid-Market        FinServ           EMEA
# 1   ACC-1091      Yarrow Group         SMB  Manufacturing           EMEA
# 2   ACC-1195     Juniper Foods         SMB    Hospitality           APAC
# 3   ACC-1027    Helix Partners         SMB   Construction  North America
# 4   ACC-1397  Crestline Health  Mid-Market        FinServ  North America
#
#   signup_date contract_start_date contract_end_date billing_term  \
# 0  2026-03-21          2026-03-21        2026-04-04      monthly
# 1  2023-05-24          2023-05-24        2026-08-19      monthly
# 2  2024-11-22          2024-11-22        2026-07-27       annual
# 3  2024-11-19          2024-11-19        2026-08-05      monthly
# 4  2022-11-02          2022-11-02        2025-09-20      monthly
#
#    contract_value  ...  mau_score  usage_score  support_score  \
# 0         3326.91  ...         10            0              7
# 1          476.33  ...          0            5              7
# 2         2389.31  ...          0            5              4
# 3          614.96  ...          0           10             10
# 4         6921.84  ...         10            5             10
#
#    escalation_score  revenue_score  renewal_score  customer_health_score  \
# 0                 7              5              5                     34
# 1                 7              5             15                     39
# 2                 7              5             10                     41
# 3                 4              5             15                     44
# 4                 4             10              5                     44
#
#    customer_status  priority_score  priority_rank
# 0          At Risk            54.0              1
# 1          At Risk            53.5              2
# 2          At Risk            51.5              3
# 3          At Risk            51.0              4
# 4          At Risk            50.5              5
#
# [5 rows x 44 columns]

# %%
df["segment"].value_counts()
# Out:
# segment
# SMB           27
# Mid-Market    13
# Name: count, dtype: int64

# %%
df["segment"].value_counts().plot(
    kind="bar",
    color="red",
    figsize=(6,4)
)

plt.title("Customer Segment Distribution")
plt.ylabel("Number of Customers")
plt.show()

# %%
df["industry"].value_counts()
# Out:
# industry
# Hospitality      9
# SaaS             9
# FinServ          4
# Healthcare       4
# Education        3
# Logistics        3
# Manufacturing    2
# Construction     2
# Retail           2
# Media            2
# Name: count, dtype: int64

# %%
df["industry"].value_counts().plot(
    kind="bar",
    figsize=(8,5),
    color="orange"
)

plt.title("Industry Distribution")
plt.show()

# %%
df["region"].value_counts()
# Out:
# region
# North America    22
# EMEA             10
# APAC              8
# Name: count, dtype: int64

# %%
df["region"].value_counts().plot(
    kind="bar",
    color="green",
    figsize=(7,4)
)

plt.title("Region Distribution")
plt.show()

# %%
df[[
    "seat_utilization",
    "avg_mau",
    "support_tickets_90d",
    "escalations_90d",
    "csat"
]].mean()
# Out:
# seat_utilization       45.219439
# avg_mau                 9.837500
# support_tickets_90d     4.825000
# escalations_90d         1.050000
# csat                    3.317500
# dtype: float64
