# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../top_40_priority_customers.csv")

# %%
df.head()
# Out:
#   account_id    account_name     segment       industry         region  \
# 0   ACC-1091    Yarrow Group         SMB  Manufacturing           EMEA
# 1   ACC-1027  Helix Partners         SMB   Construction  North America
# 2   ACC-1344  Pinnacle Media         SMB           SaaS  North America
# 3   ACC-1169  Vista Partners  Mid-Market      Education  North America
# 4   ACC-1195   Juniper Foods         SMB    Hospitality           APAC
#
#   signup_date contract_start_date contract_end_date billing_term  \
# 0  2023-05-24          2023-05-24        2026-08-19      monthly
# 1  2024-11-19          2024-11-19        2026-08-05      monthly
# 2  2025-11-06          2025-11-06        2026-11-10       annual
# 3  2023-01-07          2023-01-07        2027-01-03       annual
# 4  2024-11-22          2024-11-22        2026-07-27       annual
#
#    contract_value  ...  mau_score  usage_score  support_score  \
# 0          476.33  ...          0            5              7
# 1          614.96  ...          0           10             10
# 2         4769.00  ...          0            5             10
# 3        73368.19  ...         15            0              7
# 4         2389.31  ...          0            5              4
#
#    escalation_score  revenue_score  renewal_score  customer_health_score  \
# 0                 7              5             15                     39
# 1                 4              5             15                     44
# 2                10             10             10                     45
# 3                 0             20             10                     52
# 4                 7              5             15                     46
#
#    customer_status  priority_score  priority_rank
# 0          At Risk            48.5              1
# 1          At Risk            46.0              2
# 2          At Risk            46.0              3
# 3          Monitor            45.5              4
# 4          At Risk            45.0              5
#
# [5 rows x 44 columns]

# %%
df["segment"].value_counts()
# Out:
# segment
# SMB           30
# Mid-Market     8
# Enterprise     2
# Name: count, dtype: int64

# %%
df["segment"].value_counts().plot(
    kind="bar",
    color="red",
    figsize=(6,4)
)

plt.title("Customer Segment Distribution")
plt.ylabel("Number of Customers")
plt.show()

# %%
df["industry"].value_counts()
# Out:
# industry
# FinServ          9
# Hospitality      7
# SaaS             5
# Education        4
# Manufacturing    3
# Retail           3
# Logistics        3
# Media            3
# Healthcare       2
# Construction     1
# Name: count, dtype: int64

# %%
df["industry"].value_counts().plot(
    kind="bar",
    figsize=(8,5),
    color="orange"
)

plt.title("Industry Distribution")
plt.show()

# %%
df["region"].value_counts()
# Out:
# region
# North America    21
# EMEA             11
# APAC              8
# Name: count, dtype: int64

# %%
df["region"].value_counts().plot(
    kind="bar",
    color="green",
    figsize=(7,4)
)

plt.title("Region Distribution")
plt.show()

# %%
df[[
    "seat_utilization",
    "avg_mau",
    "support_tickets_90d",
    "escalations_90d",
    "csat"
]].mean()
# Out:
# seat_utilization       45.854929
# avg_mau                15.245833
# support_tickets_90d     4.300000
# escalations_90d         1.075000
# csat                    3.365000
# dtype: float64
