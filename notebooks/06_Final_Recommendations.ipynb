# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../top_40_priority_customers.csv")

# %%
df.head()
# Out:
#   account_id    account_name     segment       industry         region  \
# 0   ACC-1091    Yarrow Group         SMB  Manufacturing           EMEA
# 1   ACC-1169  Vista Partners  Mid-Market      Education  North America
# 2   ACC-1344  Pinnacle Media         SMB           SaaS  North America
# 3   ACC-1027  Helix Partners         SMB   Construction  North America
# 4   ACC-1157  Quantum Supply         SMB     Healthcare           APAC
#
#   signup_date contract_start_date contract_end_date billing_term  \
# 0  2023-05-24          2023-05-24        2026-08-19      monthly
# 1  2023-01-07          2023-01-07        2027-01-03       annual
# 2  2025-11-06          2025-11-06        2026-11-10       annual
# 3  2024-11-19          2024-11-19        2026-08-05      monthly
# 4  2022-11-11          2022-11-11        2026-08-28      monthly
#
#    contract_value  ...  usage_score  support_score  escalation_score  \
# 0          476.33  ...            5              7                 7
# 1        73368.19  ...            0              7                 0
# 2         4769.00  ...            5             10                10
# 3          614.96  ...           10             10                 4
# 4          362.79  ...            5              7                 4
#
#    revenue_score  customer_health_score  customer_status  renewal_score  \
# 0              5                     39          At Risk             15
# 1             20                     47          At Risk              5
# 2              5                     40          At Risk             10
# 3              5                     44          At Risk             15
# 4              5                     46          At Risk             15
#
#    csat_missing  priority_score  priority_rank
# 0             0            48.5              1
# 1             0            47.0              2
# 2             0            47.0              3
# 3             0            46.0              4
# 4             0            45.0              5
#
# [5 rows x 43 columns]

# %%
df["segment"].value_counts()
# Out:
# segment
# SMB           32
# Mid-Market     7
# Enterprise     1
# Name: count, dtype: int64

# %%
df["segment"].value_counts().plot(
    kind="bar",
    color="red",
    figsize=(6,4)
)

plt.title("Customer Segment Distribution")
plt.ylabel("Number of Customers")
plt.show()

# %%
df["industry"].value_counts()
# Out:
# industry
# Hospitality      10
# FinServ           8
# Education         4
# SaaS              4
# Logistics         3
# Media             3
# Retail            3
# Manufacturing     2
# Healthcare        2
# Construction      1
# Name: count, dtype: int64

# %%
df["industry"].value_counts().plot(
    kind="bar",
    figsize=(8,5),
    color="orange"
)

plt.title("Industry Distribution")
plt.show()

# %%
df["region"].value_counts()
# Out:
# region
# North America    21
# EMEA             10
# APAC              9
# Name: count, dtype: int64

# %%
df["region"].value_counts().plot(
    kind="bar",
    color="green",
    figsize=(7,4)
)

plt.title("Region Distribution")
plt.show()

# %%
df[[
    "seat_utilization",
    "avg_mau",
    "support_tickets_90d",
    "escalations_90d",
    "csat"
]].mean()
# Out:
# seat_utilization       46.367580
# avg_mau                11.683333
# support_tickets_90d     4.500000
# escalations_90d         1.050000
# csat                    3.405000
# dtype: float64
